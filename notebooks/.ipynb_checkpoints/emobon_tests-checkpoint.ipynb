# %% [markdown]
# # EMOBON data wrangling
#
# This jupyter lab notebook is for checking all the available data that is present in emobon

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: pysema in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (0.1.0)
# Requirement already satisfied: jupyter in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: jupyterlab in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (4.0.7)
# Requirement already satisfied: jupyterlab_widgets in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (3.0.14)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (2.2.4)
# Requirement already satisfied: ipympl in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (0.9.7)
# Requirement already satisfied: mplcursors in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (0.6)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (2.2.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (3.10.1)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (8.1.6)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (6.0.1)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (0.13.2)
# Requirement already satisfied: apscheduler<4.0.0,>=3.10.4 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (3.11.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: pyshacl<0.27.0,>=0.26.0 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (0.26.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: rdflib<8.0.0,>=7.0.0 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (7.1.4)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (68.2.2)
# Requirement already satisfied: typeguard<5.0.0,>=4.3.0 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (4.4.2)
# Requirement already satisfied: uritemplate<5.0.0,>=4.1.1 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (4.1.1)
# Requirement already satisfied: urllib3<3.0.0,>=2.2.2 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: urnparse<0.3.0,>=0.2.2 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: validators<0.29.0,>=0.28.3 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (0.28.3)
# Requirement already satisfied: watchdog<5.0.0,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from pysema->-r requirements.txt (line 4)) (4.0.2)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 5)) (7.0.6)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 5)) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 5)) (7.9.2)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 5)) (6.25.2)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 6)) (2.0.4)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 6)) (5.4.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 6)) (2.8.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.19.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 6)) (2.25.0)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/conda/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 6)) (0.2.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 6)) (23.2)
# Requirement already satisfied: tornado>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 6)) (6.3.3)
# Requirement already satisfied: traitlets in /opt/conda/lib/python3.11/site-packages (from jupyterlab->-r requirements.txt (line 6)) (5.11.2)
# Requirement already satisfied: ipython<10 in /opt/conda/lib/python3.11/site-packages (from ipympl->-r requirements.txt (line 9)) (8.16.1)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.11/site-packages (from ipympl->-r requirements.txt (line 9)) (11.1.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 11)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 11)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 12)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 12)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 12)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 12)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 12)) (3.2.3)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from ipywidgets->-r requirements.txt (line 13)) (0.1.4)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/conda/lib/python3.11/site-packages (from ipywidgets->-r requirements.txt (line 13)) (4.0.14)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/lib/python3.11/site-packages (from plotly->-r requirements.txt (line 14)) (1.35.0)
# Requirement already satisfied: tzlocal>=3.0 in /opt/conda/lib/python3.11/site-packages (from apscheduler<4.0.0,>=3.10.4->pysema->-r requirements.txt (line 4)) (5.3.1)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.11/site-packages (from ipython<10->ipympl->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython<10->ipympl->-r requirements.txt (line 9)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython<10->ipympl->-r requirements.txt (line 9)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.11/site-packages (from ipython<10->ipympl->-r requirements.txt (line 9)) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.11/site-packages (from ipython<10->ipympl->-r requirements.txt (line 9)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.11/site-packages (from ipython<10->ipympl->-r requirements.txt (line 9)) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from ipython<10->ipympl->-r requirements.txt (line 9)) (2.16.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.11/site-packages (from ipython<10->ipympl->-r requirements.txt (line 9)) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython<10->ipympl->-r requirements.txt (line 9)) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2<4.0.0,>=3.1.4->pysema->-r requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (8.4.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (0.4.4)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (5.9.2)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (7.4.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (0.17.1)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (25.1.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (0.17.1)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.6.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.11/site-packages (from jupyter-core->jupyterlab->-r requirements.txt (line 6)) (3.11.0)
# Requirement already satisfied: babel>=2.10 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab->-r requirements.txt (line 6)) (2.13.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab->-r requirements.txt (line 6)) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/conda/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab->-r requirements.txt (line 6)) (4.19.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: html5lib<2,>=1.1 in /opt/conda/lib/python3.11/site-packages (from pyshacl<0.27.0,>=0.26.0->pysema->-r requirements.txt (line 4)) (1.1)
# Requirement already satisfied: importlib-metadata>6 in /opt/conda/lib/python3.11/site-packages (from pyshacl<0.27.0,>=0.26.0->pysema->-r requirements.txt (line 4)) (6.8.0)
# Requirement already satisfied: owlrl<7,>=6.0.2 in /opt/conda/lib/python3.11/site-packages (from pyshacl<0.27.0,>=0.26.0->pysema->-r requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: prettytable>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from pyshacl<0.27.0,>=0.26.0->pysema->-r requirements.txt (line 4)) (3.16.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->pysema->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->pysema->-r requirements.txt (line 4)) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->pysema->-r requirements.txt (line 4)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->pysema->-r requirements.txt (line 4)) (2023.7.22)
# Requirement already satisfied: typing_extensions>=4.10.0 in /opt/conda/lib/python3.11/site-packages (from typeguard<5.0.0,>=4.3.0->pysema->-r requirements.txt (line 4)) (4.13.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (1.5.8)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (5.9.5)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata>6->pyshacl<0.27.0,>=0.26.0->pysema->-r requirements.txt (line 4)) (3.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython<10->ipympl->-r requirements.txt (line 9)) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->-r requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->-r requirements.txt (line 6)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->-r requirements.txt (line 6)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab->-r requirements.txt (line 6)) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (2.18.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.11/site-packages (from pexpect>4.3->ipython<10->ipympl->-r requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prettytable>=3.5.0->pyshacl<0.27.0,>=0.26.0->pysema->-r requirements.txt (line 4)) (0.2.8)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 5)) (2.5)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython<10->ipympl->-r requirements.txt (line 9)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython<10->ipympl->-r requirements.txt (line 9)) (2.4.0)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython<10->ipympl->-r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (2.4)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 6)) (2.8.19.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
from conneg_functions import execute_to_df, generate_sparql

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import textwrap
from IPython.core.display import HTML
import ipywidgets as widgets
from ipywidgets import interact
from IPython.display import display, clear_output

# disabel if using labnotebook , for normal notebook enable for interactive plots
#%matplotlib widget

# %% [markdown]
# ## All col names present for a sample

# %%
df = execute_to_df('column_names.sparql')
HTML("""
<style>
    .dataframe td, .dataframe th {
        min-width: 500px;
        word-wrap: break-word;
    }
</style>
""" + df.to_html())
# Out:
# <style>
#     .dataframe td, .dataframe th {
#         min-width: 500px;
#         word-wrap: break-word;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>s</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ## All observations with links to results

# %%
observation_results = execute_to_df('all_observation_results.sparql')
observation_results
# Out:
#                                            observations  \
# 0     http://data.emobon.embrc.eu/observatory-nrmcb-...
# 1     http://data.emobon.embrc.eu/observatory-nrmcb-...
# 2     http://data.emobon.embrc.eu/observatory-nrmcb-...
# 3     http://data.emobon.embrc.eu/observatory-nrmcb-...
# 4     http://data.emobon.embrc.eu/observatory-nrmcb-...
# ...                                                 ...
# 9007  http://data.emobon.embrc.eu/observatory-nrmcb-...
# 9008  http://data.emobon.embrc.eu/observatory-nrmcb-...
# 9009  http://data.emobon.embrc.eu/observatory-nrmcb-...
# 9010  http://data.emobon.embrc.eu/observatory-nrmcb-...
# 9011  http://data.emobon.embrc.eu/observatory-nrmcb-...
#
#                                                property  \
# 0     http://vocab.nerc.ac.uk/collection/P02/current...
# 1     http://vocab.nerc.ac.uk/collection/P02/current...
# 2     http://vocab.nerc.ac.uk/collection/P02/current...
# 3     http://vocab.nerc.ac.uk/collection/P02/current...
# 4     http://vocab.nerc.ac.uk/collection/P02/current...
# ...                                                 ...
# 9007  http://vocab.nerc.ac.uk/collection/P02/current...
# 9008  http://vocab.nerc.ac.uk/collection/P02/current...
# 9009  http://vocab.nerc.ac.uk/collection/P02/current...
# 9010  http://vocab.nerc.ac.uk/collection/P02/current...
# 9011  http://vocab.nerc.ac.uk/collection/P02/current...
#
#                                       observationresult  \
# 0     https://rdflib.github.io/.well-known/genid/rdf...
# 1     https://rdflib.github.io/.well-known/genid/rdf...
# 2     https://rdflib.github.io/.well-known/genid/rdf...
# 3     https://rdflib.github.io/.well-known/genid/rdf...
# 4     https://rdflib.github.io/.well-known/genid/rdf...
# ...                                                 ...
# 9007  https://rdflib.github.io/.well-known/genid/rdf...
# 9008  https://rdflib.github.io/.well-known/genid/rdf...
# 9009  https://rdflib.github.io/.well-known/genid/rdf...
# 9010  https://rdflib.github.io/.well-known/genid/rdf...
# 9011  https://rdflib.github.io/.well-known/genid/rdf...
#
#                                                    unit resultnumeric  \
# 0     http://vocab.nerc.ac.uk/collection/P06/current...          0.04
# 1     http://vocab.nerc.ac.uk/collection/P06/current...          0.05
# 2     http://vocab.nerc.ac.uk/collection/P06/current...          0.08
# 3     http://vocab.nerc.ac.uk/collection/P06/current...          0.05
# 4     http://vocab.nerc.ac.uk/collection/P06/current...          0.03
# ...                                                 ...           ...
# 9007  http://vocab.nerc.ac.uk/collection/P06/current...           1,6
# 9008  http://vocab.nerc.ac.uk/collection/P06/current...          0,86
# 9009  http://vocab.nerc.ac.uk/collection/P06/current...          0,86
# 9010  http://vocab.nerc.ac.uk/collection/P06/current...          2,56
# 9011  http://vocab.nerc.ac.uk/collection/P06/current...          2,56
#
#                                                  sample  \
# 0     http://data.emobon.embrc.eu/observatory-nrmcb-...
# 1     http://data.emobon.embrc.eu/observatory-nrmcb-...
# 2     http://data.emobon.embrc.eu/observatory-nrmcb-...
# 3     http://data.emobon.embrc.eu/observatory-nrmcb-...
# 4     http://data.emobon.embrc.eu/observatory-nrmcb-...
# ...                                                 ...
# 9007  http://data.emobon.embrc.eu/observatory-nrmcb-...
# 9008  http://data.emobon.embrc.eu/observatory-nrmcb-...
# 9009  http://data.emobon.embrc.eu/observatory-nrmcb-...
# 9010  http://data.emobon.embrc.eu/observatory-nrmcb-...
# 9011  http://data.emobon.embrc.eu/observatory-nrmcb-...
#
#                                          metadatasample propertyaltlabel
# 0     http://data.emobon.embrc.eu/observatory-nrmcb-...           WC_PO4
# 1     http://data.emobon.embrc.eu/observatory-nrmcb-...           WC_PO4
# 2     http://data.emobon.embrc.eu/observatory-nrmcb-...           WC_PO4
# 3     http://data.emobon.embrc.eu/observatory-nrmcb-...           WC_PO4
# 4     http://data.emobon.embrc.eu/observatory-nrmcb-...           WC_PO4
# ...                                                 ...              ...
# 9007  http://data.emobon.embrc.eu/observatory-nrmcb-...    Sed_PhaeoPigs
# 9008  http://data.emobon.embrc.eu/observatory-nrmcb-...    Sed_PhaeoPigs
# 9009  http://data.emobon.embrc.eu/observatory-nrmcb-...    Sed_PhaeoPigs
# 9010  http://data.emobon.embrc.eu/observatory-nrmcb-...    Sed_PhaeoPigs
# 9011  http://data.emobon.embrc.eu/observatory-nrmcb-...    Sed_PhaeoPigs
#
# [9012 rows x 8 columns]

# %% [markdown]
# ## percentage of measured properties for all samples

# %%
# Get the list of distinct observations and properties
distinct_observations = observation_results['sample'].unique()
distinct_properties = observation_results['propertyaltlabel'].unique()

# Create a new DataFrame with observations as rows and properties as columns
new_df = pd.DataFrame(index=distinct_observations, columns=distinct_properties)

# Populate the DataFrame with True/False values
for observation in distinct_observations:
    for property in distinct_properties:
        new_df.loc[observation, property] = property in observation_results[observation_results['sample'] == observation]['propertyaltlabel'].values

# Convert the DataFrame values to boolean
new_df = new_df.fillna(False).astype(bool)

# Reset the index to make observations a column
# new_df.reset_index(inplace=True)
# new_df.rename(columns={'index': 'sample'}, inplace=True)

# Count the number of True/False values for each property
true_counts = new_df.sum(axis=0)
false_counts = len(new_df) - true_counts

# Calculate the percentage of True/False values for each property
true_percentages = ((true_counts / len(new_df)) * 100).round().astype(int)
false_percentages = ((false_counts / len(new_df)) * 100).round().astype(int)

# Create a stacked bar chart
plt.figure(figsize=(10, 6))
bar_width = 0.5
index = range(len(distinct_properties))

# Extract the last 6 characters of each property for the x-axis labels
property_labels = [prop[:] for prop in distinct_properties]

bars_true = plt.bar(index, true_percentages, bar_width, label='Present', color='skyblue')
bars_false = plt.bar(index, false_percentages, bar_width, bottom=true_percentages, label='Missing', color='lightcoral')

plt.xlabel('Properties')
plt.ylabel('Percentage (%)')
plt.title('Percentage of Present/Missing properties for all samples')
plt.xticks(index, property_labels, rotation=45)
plt.legend()

# Add the percentage amount in each respective bar
for bar in bars_true:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height / 2, f'{height}%', ha='center', va='bottom', color='black')

for i, bar in enumerate(bars_false):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, true_percentages[i] + height / 2, f'{height}%', ha='center', va='bottom', color='black')
    #plt.text(bar.get_x() + bar.get_width() / 2, true_percentages[i] + height + 1, f'{height:.1f}%', ha='center', va='bottom', color='black')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_744/4021603329.py:14: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   new_df = new_df.fillna(False).astype(bool)
# /tmp/ipykernel_744/4021603329.py:52: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(bar.get_x() + bar.get_width() / 2, true_percentages[i] + height / 2, f'{height}%', ha='center', va='bottom', color='black')

# %% [markdown]
# ## All unique properties found for all observation results

# %%
unique_props = execute_to_df('distinct_properties.sparql')
unique_props
# Out:
#                                                property
# 0     https://rdflib.github.io/.well-known/genid/rdf...
# 1     https://rdflib.github.io/.well-known/genid/rdf...
# 2     https://rdflib.github.io/.well-known/genid/rdf...
# 3     https://rdflib.github.io/.well-known/genid/rdf...
# 4     https://rdflib.github.io/.well-known/genid/rdf...
# ...                                                 ...
# 6531  https://rdflib.github.io/.well-known/genid/rdf...
# 6532  https://rdflib.github.io/.well-known/genid/rdf...
# 6533  https://rdflib.github.io/.well-known/genid/rdf...
# 6534  https://rdflib.github.io/.well-known/genid/rdf...
# 6535  https://rdflib.github.io/.well-known/genid/rdf...
#
# [6536 rows x 1 columns]

# %%
observations_by_sample = execute_to_df('count_by_sample.sparql')
observations_by_sample
# Out:
#                                                  sample  observationCount
# 0     http://data.emobon.embrc.eu/observatory-osd74-...                15
# 1     http://data.emobon.embrc.eu/observatory-osd74-...                 7
# 2     http://data.emobon.embrc.eu/observatory-osd74-...                15
# 3     http://data.emobon.embrc.eu/observatory-osd74-...                15
# 4     http://data.emobon.embrc.eu/observatory-osd74-...                15
# ...                                                 ...               ...
# 1543  http://data.emobon.embrc.eu/observatory-rformo...                 7
# 1544  http://data.emobon.embrc.eu/observatory-rformo...                 8
# 1545  http://data.emobon.embrc.eu/observatory-rformo...                 8
# 1546  http://data.emobon.embrc.eu/observatory-rformo...                 8
# 1547  http://data.emobon.embrc.eu/observatory-rformo...                 8
#
# [1548 rows x 2 columns]

# %%
# barplot for the ammount of times a certain ammount of observations has happened

# Group by 'sample' and count the occurrences
observation_counts = observations_by_sample.groupby('observationCount').size().reset_index(name='count')

# Create a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(observation_counts['observationCount'], observation_counts['count'], color='skyblue')
plt.title('count of distinct properties measured per observation')
plt.xlabel('Amount of properties measured in sample')
plt.ylabel('Amount #')
plt.xticks(rotation=45)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, int(yval), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
count_by_property = execute_to_df('count_by_property.sparql')
count_by_property
# Out:
#                                              property  observationCount
# 0   http://vocab.nerc.ac.uk/collection/P02/current...               255
# 1   http://vocab.nerc.ac.uk/collection/A05/current...              1501
# 2   http://vocab.nerc.ac.uk/collection/P02/current...               431
# 3   http://vocab.nerc.ac.uk/collection/C67/current...               319
# 4   http://vocab.nerc.ac.uk/collection/P01/current...               431
# 5   http://vocab.nerc.ac.uk/collection/P35/current...               255
# 6   http://vocab.nerc.ac.uk/collection/P09/current...               100
# 7   http://vocab.nerc.ac.uk/collection/P01/current...               748
# 8   http://vocab.nerc.ac.uk/collection/P02/current...              1505
# 9   http://vocab.nerc.ac.uk/collection/P35/current...               510
# 10  http://vocab.nerc.ac.uk/collection/P02/current...               510
# 11  http://vocab.nerc.ac.uk/collection/P01/current...               383
# 12  http://vocab.nerc.ac.uk/collection/P01/current...               431
# 13                                     organism_count               255
# 14  http://vocab.nerc.ac.uk/collection/S27/current...               557
# 15  http://vocab.nerc.ac.uk/collection/P01/current...               191
# 16  https://vocab.lternet.edu/vocab/vocab/index.ph...               207
# 17  http://vocab.nerc.ac.uk/collection/P02/current...               431
# 18  http://vocab.nerc.ac.uk/collection/S06/current...               454

# %%
# Extract the last 6 characters of the property column
count_by_property['property_label'] = count_by_property['property'].apply(lambda x: x[-6:])

plt.figure(figsize=(12, 6))
# Create the bar plot
bars = plt.bar(count_by_property['property_label'], count_by_property['observationCount'], color='blue', edgecolor='black')

# Add labels and a title
plt.xlabel('Property (last 6 characters)')
plt.ylabel('Observation Count')
plt.title('Observation Count by Property')

# Add the amount of observations above the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, int(yval), ha='center', va='bottom')

# Show the plot
plt.show()

# %%
values_per_property = []
for property_uri in unique_props['property']:
    try:
        print(property_uri)
        df = execute_to_df(name='get_values_by_property.sparql',uri=property_uri)
        values_per_property.append(df)
    except Exception as e:
        print(e)

values_per_property

# %%
dataframes = values_per_property
# Function to calculate the ideal number of bins using the Freedman-Diaconis rule
# Function to calculate the ideal number of bins using the Freedman-Diaconis rule
def calculate_bins(data):
    q75, q25 = np.percentile(data.dropna(), [75, 25])
    iqr = q75 - q25
    bin_width = 2 * iqr / (len(data.dropna()) ** (1/3))
    bins = int((data.max() - data.min()) / bin_width)
    return bins

# Create a list to store the property and bins information
property_bins_list = []

# Iterate over each DataFrame in the list
for df in dataframes:
    try:
        # Ensure the 'resultnumeric' column data is numeric
        df['resultnumeric'] = pd.to_numeric(df['resultnumeric'], errors='coerce')
        # Check if the length of the 'resultnumeric' column is greater than 0
        if len(df['resultnumeric'].dropna()) > 0:
            # Get the first property value
            property_value = df['property'].iloc[0]
            # Check if the property value starts with 'http://vocab.nerc.ac.uk/'
            if property_value.startswith('http://vocab.nerc.ac.uk/'):
                # Calculate the ideal number of bins for the 'resultnumeric' column
                bins = calculate_bins(df['resultnumeric'])

                # these lines below are not correct , they enforce 30 bins max 
                #if bins > 30: 
                #    bins = 30
                # Append the property and bins information to the list
                property_bins_list.append({'property': property_value, 'bins': bins})
            else:
                raise ValueError("The 'property' value does not start with 'http://vocab.nerc.ac.uk/'.")
        else:
            raise ValueError("The 'resultnumeric' column is empty after dropping NaNs.")
    except Exception as e:
        print(f"Error processing DataFrame: {e}")

# Create a new DataFrame from the list
property_bins_df = pd.DataFrame(property_bins_list)

# Print the new DataFrame
print(property_bins_df)

# Calculate the number of rows and columns for the subplots
num_plots = len(property_bins_df)
num_cols = 2
num_rows = (num_plots + num_cols - 1) // num_cols

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, num_rows * 5))
axes = axes.flatten()

# Iterate over the property_bins_df DataFrame and plot each histogram in a subplot
for index, row in property_bins_df.iterrows():
    for df in dataframes:
        if not df.empty and df['property'].iloc[0] == row['property']:
            ax = axes[index]
            counts, bin_edges = np.histogram(df['resultnumeric'].dropna(), bins=row['bins'])
            ax.hist(df['resultnumeric'].dropna(), bins=row['bins'], edgecolor='black')
            
            # Wrap the title text
            title_text = f"Histogram of {df['propertylabel'].iloc[0]} for all observations"
            wrapped_title = "\n".join(textwrap.wrap(title_text, width=40))
            ax.set_title(wrapped_title)
            
            ax.set_xlabel(f"{df['unitlabel'].iloc[0]} ({df['unitaltlabel'].iloc[0]})")
            ax.set_ylabel('Frequency #')

            # Calculate and add the range per bin as labels
            for count, edge in zip(counts, bin_edges[:-1]):
                if count > 0:  # Only add label if the frequency is greater than 0
                    bin_range = f"{edge:.2f} - {edge + (bin_edges[1] - bin_edges[0]):.2f}"
                    ax.text(edge + (bin_edges[1] - bin_edges[0]) / 2, count / 2, bin_range, ha='center', va='center', rotation=90, color='white', fontsize=8)

# Remove any unused subplots
for i in range(num_plots, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()
# Out:
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# ...
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
# Error processing DataFrame: The 'resultnumeric' column is empty after dropping NaNs.
#                                              property    bins
# 0   http://vocab.nerc.ac.uk/collection/P02/current...      11
# 1   http://vocab.nerc.ac.uk/collection/A05/current...  458139
# 2   http://vocab.nerc.ac.uk/collection/P02/current...       3
# 3   http://vocab.nerc.ac.uk/collection/P01/current...      19
# 4   http://vocab.nerc.ac.uk/collection/P35/current...       8
# 5   http://vocab.nerc.ac.uk/collection/P01/current...    1233
# 6   http://vocab.nerc.ac.uk/collection/P02/current...    9611
# 7   http://vocab.nerc.ac.uk/collection/P01/current...      43
# 8   http://vocab.nerc.ac.uk/collection/P01/current...      25
# 9   http://vocab.nerc.ac.uk/collection/S27/current...      16
# 10  http://vocab.nerc.ac.uk/collection/P02/current...      21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 61
#      59 ax = axes[index]
#      60 counts, bin_edges = np.histogram(df['resultnumeric'].dropna(), bins=row['bins'])
# ---> 61 ax.hist(df['resultnumeric'].dropna(), bins=row['bins'], edgecolor='black')
#      63 # Wrap the title text
#      64 title_text = f"Histogram of {df['propertylabel'].iloc[0]} for all observations"
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/axes/_axes.py:7184, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7182 else:
#    7183     height = top
# -> 7184 bars = _barfunc(bins[:-1]+boffset, height, width,
#    7185                 align='center', log=log,
#    7186                 color=color, **{bottom_kwarg: bottom})
#    7187 patches.append(bars)
#    7188 if stacked:
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/axes/_axes.py:2646, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2643 args = zip(left, bottom, width, height, facecolor, edgecolor, linewidth,
#    2644            hatch, patch_labels)
#    2645 for l, b, w, h, c, e, lw, htch, lbl in args:
# -> 2646     r = mpatches.Rectangle(
#    2647         xy=(l, b), width=w, height=h,
#    2648         facecolor=c,
#    2649         edgecolor=e,
#    2650         linewidth=lw,
#    2651         label=lbl,
#    2652         hatch=htch,
#    2653         )
#    2654     r._internal_update(kwargs)
#    2655     r.get_path()._interpolation_steps = 100
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/patches.py:772, in Rectangle.__init__(self, xy, width, height, angle, rotation_point, **kwargs)
#     748 @_docstring.interpd
#     749 def __init__(self, xy, width, height, *,
#     750              angle=0.0, rotation_point='xy', **kwargs):
#     751     """
#     752     Parameters
#     753     ----------
#    (...)
#     770         %(Patch:kwdoc)s
#     771     """
# --> 772     super().__init__(**kwargs)
#     773     self._x0 = xy[0]
#     774     self._y0 = xy[1]
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/patches.py:85, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      83 else:
#      84     self.set_edgecolor(edgecolor)
# ---> 85     self.set_facecolor(facecolor)
#      87 self._linewidth = 0
#      88 self._unscaled_dash_pattern = (0, None)  # offset, dash
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/patches.py:404, in Patch.set_facecolor(self, color)
#     396 """
#     397 Set the patch face color.
#     398
#    (...)
#     401 color : :mpltype:`color` or None
#     402 """
#     403 self._original_facecolor = color
# --> 404 self._set_facecolor(color)
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/patches.py:392, in Patch._set_facecolor(self, color)
#     390     color = mpl.rcParams['patch.facecolor']
#     391 alpha = self._alpha if self._fill else 0
# --> 392 self._facecolor = colors.to_rgba(color, alpha)
#     393 self.stale = True
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/colors.py:317, in to_rgba(c, alpha)
#     315     rgba = None
#     316 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 317     rgba = _to_rgba_no_colorcycle(c, alpha)
#     318     try:
#     319         _colors_full_map.cache[c, alpha] = rgba
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/colors.py:404, in _to_rgba_no_colorcycle(c, alpha)
#     402 if len(c) not in [3, 4]:
#     403     raise ValueError("RGBA sequence should have length 3 or 4")
# --> 404 if not all(isinstance(x, Real) for x in c):
#     405     # Checks that don't work: `map(float, ...)`, `np.array(..., float)` and
#     406     # `np.array(...).astype(float)` would all convert "0.5" to 0.5.
#     407     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     408 # Return a tuple to prevent the cached value from being modified.
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/colors.py:404, in <genexpr>(.0)
#     402 if len(c) not in [3, 4]:
#     403     raise ValueError("RGBA sequence should have length 3 or 4")
# --> 404 if not all(isinstance(x, Real) for x in c):
#     405     # Checks that don't work: `map(float, ...)`, `np.array(..., float)` and
#     406     # `np.array(...).astype(float)` would all convert "0.5" to 0.5.
#     407     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     408 # Return a tuple to prevent the cached value from being modified.
#
# KeyboardInterrupt:

# %%
# same histograzms but interactive

# Function to update the plot based on the selected property
def update_plot(selected_property):
    fig, ax = plt.subplots(figsize=(10, 6))
    
    for df in dataframes:
        if not df.empty and df['property'].iloc[0] == selected_property:
            row = property_bins_df[property_bins_df['property'] == selected_property].iloc[0]
            counts, bin_edges = np.histogram(df['resultnumeric'].dropna(), bins=row['bins'])
            ax.hist(df['resultnumeric'].dropna(), bins=row['bins'], edgecolor='black')
            
            # Wrap the title text
            title_text = f"Histogram of {df['propertylabel'].iloc[0]} for all observations"
            wrapped_title = "\n".join(textwrap.wrap(title_text, width=40))
            ax.set_title(wrapped_title)
            
            ax.set_xlabel(f"{df['unitlabel'].iloc[0]} ({df['unitaltlabel'].iloc[0]})")
            ax.set_ylabel('Frequency #')

            # Calculate and add the range per bin as labels
            for count, edge in zip(counts, bin_edges[:-1]):
                if count > 0:  # Only add label if the frequency is greater than 0
                    bin_range = f"{edge:.2f} - {edge + (bin_edges[1] - bin_edges[0]):.2f}"
                    ax.text(edge + (bin_edges[1] - bin_edges[0]) / 2, count / 2, bin_range, ha='center', va='center', rotation=90, color='white', fontsize=8)
    
    plt.tight_layout()
    plt.show()

# Create a dropdown widget for selecting the property
property_dropdown = widgets.Dropdown(
    options=property_bins_df['property'].tolist(),
    description='Property:',
    disabled=False,
)

# Use the interact function to update the plot based on the selected property
interact(update_plot, selected_property=property_dropdown)

# %%
# check on the samples themselves

# get the types of samples

types_samples = execute_to_df(name='types_samples.sparql')
# Display DataFrame with CSS styling
HTML("""
<style>
    .dataframe td, .dataframe th {
        min-width: 200px;
        word-wrap: break-word;
    }
</style>
""" + types_samples.to_html())

# %% [markdown]
# ## remarks
#
# The links to ncbi shown above lead to nowhere , what is the deal with this?

# %%
extended_obs = execute_to_df("extended_observations_with_metadata.sparql")
extended_obs

df = extended_obs

# Identify columns with fewer than 20 unique values
columns_to_filter = [col for col in df.columns if df[col].nunique() < 20]

# Create a dictionary to store the widgets for each column
filter_widgets = {}

# Create an output widget to display the filtered DataFrame
output = widgets.Output()

# Create a function to update the filtered DataFrame
def update_filtered_df(*args):
    filtered_df = df.copy()
    for col, widget in filter_widgets.items():
        if widget.value != 'All':
            filtered_df = filtered_df[filtered_df[col] == widget.value]
    with output:
        clear_output(wait=True)
        display(filtered_df)

# Create widgets for each column and add them to the filter_widgets dictionary
for col in columns_to_filter:
    unique_values = ['All'] + df[col].unique().tolist()
    widget = widgets.Dropdown(
        options=unique_values,
        description=col,
        value='All'
    )
    widget.observe(update_filtered_df, names='value')
    filter_widgets[col] = widget

# Display the widgets
for widget in filter_widgets.values():
    display(widget)

# Display the initial DataFrame
display(output)
update_filtered_df()  # Initial call to display the full DataFrame

# %%
# interactive boxplots
# Create a dictionary to store the widgets for each column
# Ensure the 'resultnumeric' column data is numeric and handle errors
try:
    df['resultnumeric'] = pd.to_numeric(df['resultnumeric'], errors='coerce')
except Exception as e:
    print(e)
    pass

# Drop rows with NaN values in 'resultnumeric'
df = df.dropna(subset=['resultnumeric'])

# Identify columns with fewer than 20 unique values (excluding 'resultnumeric', 'property', 'unit', and 'propertyaltlabel')
columns_to_filter = [col for col in df.columns if df[col].nunique() < 20 and col not in ['resultnumeric', 'property', 'unit', 'propertyaltlabel','unitlabel','unitaltlabel']]

# Create a dictionary to store the widgets for each column
filter_widgets = {}

# Create an output widget to display the boxplot
output = widgets.Output()

# Create a function to update the boxplot based on the selected category and propertyaltlabel
def update_boxplot(selected_category, selected_propertyaltlabel):
    with output:
        clear_output(wait=True)
        filtered_df = df.copy()
        if selected_propertyaltlabel != 'All':
            filtered_df = filtered_df[filtered_df['propertyaltlabel'] == selected_propertyaltlabel]
        
        # Extract unitlabel and unitaltlabel from the first row of the filtered DataFrame
        if not filtered_df.empty:
            unitlabel = filtered_df.iloc[0]['unitlabel']
            unitaltlabel = filtered_df.iloc[0]['unitaltlabel']
            ylabel = f'{unitlabel} ({unitaltlabel})'
        else:
            ylabel = 'resultnumeric'
        
        fig, ax = plt.subplots(figsize=(10, 6))
        
        # Customize the boxplot appearance
        boxprops = dict(linestyle='-', linewidth=2, color='blue')
        whiskerprops = dict(linestyle='--', linewidth=2, color='green')
        capprops = dict(linestyle='-', linewidth=2, color='red')
        medianprops = dict(linestyle='-', linewidth=2, color='orange')
        meanprops = dict(marker='o', markerfacecolor='black', markeredgecolor='black', markersize=10)
        
        filtered_df.boxplot(column='resultnumeric', by=selected_category, ax=ax,
                            boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops,
                            medianprops=medianprops, meanprops=meanprops, showmeans=True)
        
        # Rotate x-axis labels 45 degrees and truncate them to 30 characters
        ax.set_xticklabels([label.get_text()[:30] for label in ax.get_xticklabels()], rotation=45, ha='right')
        
        plt.title(f'Boxplot of resultnumeric by {selected_category} (propertyaltlabel: {selected_propertyaltlabel})')
        plt.suptitle('')
        plt.xlabel(selected_category)
        plt.ylabel(ylabel)
        plt.grid(True)
        plt.show()

# Create widgets for each column and add them to the filter_widgets dictionary
for col in columns_to_filter:
    unique_values = ['All'] + df[col].unique().tolist()
    widget = widgets.Dropdown(
        options=unique_values,
        description=col,
        value='All'
    )
    filter_widgets[col] = widget

# Create a dropdown widget for selecting the category
category_dropdown = widgets.Dropdown(
    options=columns_to_filter,
    description='Category:',
    disabled=False
)

# Create a dropdown widget for selecting the propertyaltlabel
propertyaltlabel_dropdown = widgets.Dropdown(
    options= df['propertyaltlabel'].unique().tolist(),
    description='PropertyAltLabel:',
    disabled=False
)

# Function to update the plot when any dropdown value changes
def on_change(change):
    update_boxplot(category_dropdown.value, propertyaltlabel_dropdown.value)

# Attach the on_change function to the dropdowns
category_dropdown.observe(on_change, names='value')
propertyaltlabel_dropdown.observe(on_change, names='value')

# Display the widgets
display(category_dropdown)
display(propertyaltlabel_dropdown)
display(output)

# Initial call to display the boxplot
update_boxplot(category_dropdown.value, propertyaltlabel_dropdown.value)

# %%
# section to check if the uri's used for making all the emobon triples do match the descriptions given in the emobon ontologies
# this was not needed since the fault was with pyloade-to-pages fragment ids not being synced up with the actual fragment ids they should have had
